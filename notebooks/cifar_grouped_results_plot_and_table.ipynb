# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats


sns.set_style("whitegrid")
sns.set(font='serif')
sns.set_style("white", {
  "font.family": "serif",
  "font.serif": ["Times", "Palatino", "serif"],
})

FILENAME = 'official_10folds_results_resnet50_xception'

# %%
def plot_results(df):
    unique_values = df['model'].unique()

    resnet_results = df[df['model'] == unique_values[0]]
    xception_results = df[df['model'] == unique_values[1]]

    fig, axes = plt.subplots(1, 2, figsize=(22, 10))

    x_min = 0.3
    x_max = 0.9

    for i, plot in enumerate([
        {"df": resnet_results, "model": "ResNet50"},
        {"df": xception_results, "model": "Xception"}
    ]):
        ax = sns.pointplot(
            data=plot['df'],
            x='f1-score(weighted avg)',
            y='Severity',
            hue='strategy',
            linestyles='none',
            errorbar="ci",
            dodge=.7,
            err_kws={'linewidth': 3},
            ax=axes[i]  # Specify which subplot to use
        )

        ax.set_xlabel("F1-Score", fontsize=42)
        ax.set_xlim(x_min, x_max)

        if i == 0:
            ax.set_ylabel("", fontsize=42)
        else:
            ax.set_yticklabels([])
            ax.set_ylabel("")

        ax.axhline(y=0.5, color='grey', linestyle='--', linewidth=1)
        ax.axhline(y=1.5, color='grey', linestyle='--', linewidth=1)
        ax.axhline(y=2.5, color='grey', linestyle='--', linewidth=1)
        ax.tick_params(axis='x', labelsize=32)
        ax.tick_params(axis='y', labelsize=24)
        ax.set_title(plot['model'], fontsize=42)

        # Remove the first and last x ticks
        x_ticks = ax.get_xticks()
        ax.set_xticks(x_ticks[1:-1])  # Skip the first and last ticks

    axes[0].legend_.remove()
    axes[1].legend_.remove()

    handles, labels = ax.get_legend_handles_labels()

    for handle in handles:
        handle.set_marker('o')  # Ensure it uses a circle marker
        handle.set_markersize(30)  # Increase the marker size
        
    fig.legend(handles, labels, title="Strategy", loc='lower center', bbox_to_anchor=(0.5, -0.42), fontsize=42, title_fontsize=42, ncol=3)
    fig.suptitle('Distributions Domain Range', fontsize=50, y=1)
    plt.tight_layout()
    plt.savefig('../output/results_ci_each_domain.pdf', bbox_inches='tight')
    plt.show()

# %%
results = pd.read_csv(f'../results/cifar10/{FILENAME}.csv')
results['evaluation_set'] = results['evaluation_set'].str.replace(' 3', '')
results['Severity'] = results['Severity'].fillna('In-Distribution')

# %% [markdown]
# # Out of Distribution Stratified by Corruption Type

# %%
plot_results(results)

# %%
def bootstrap_confidence_interval(data, num_samples=1000, ci=0.95):
    data = np.array(data)

    res = stats.bootstrap((data,), np.mean, confidence_level=ci, n_resamples=num_samples, method='basic')
    return res.confidence_interval.low, res.confidence_interval.high

# %%
grouped = results.groupby(['model', 'strategy', 'Severity'])
confidence_intervals = grouped['f1-score(weighted avg)'].apply(lambda x: bootstrap_confidence_interval(x.values))
average_fscore = grouped['f1-score(weighted avg)'].mean()

confidence_intervals_df = pd.DataFrame({
    'Model': confidence_intervals.index.get_level_values('model'),
    'strategy': confidence_intervals.index.get_level_values('strategy'),
    'Severity': confidence_intervals.index.get_level_values('Severity'),
    'F-Score 95%': [f"{avg:.4f} ({lower:.4f}, {upper:.4f})" for (avg, (lower, upper)) in zip(average_fscore, confidence_intervals)]
})

confidence_intervals_df
# Out:
#        Model             strategy         Severity              F-Score 95%
# 0   ResNet50             Baseline          Highest  0.4798 (0.4628, 0.4971)
# 1   ResNet50             Baseline  In-Distribution  0.6638 (0.6228, 0.7019)
# 2   ResNet50             Baseline           Lowest  0.6319 (0.6227, 0.6425)
# 3   ResNet50             Baseline        Mid-Range  0.5662 (0.5581, 0.5739)
# 4   ResNet50           DefaultAug          Highest  0.6307 (0.6125, 0.6490)
# 5   ResNet50           DefaultAug  In-Distribution  0.8166 (0.8073, 0.8264)
# 6   ResNet50           DefaultAug           Lowest  0.7811 (0.7769, 0.7855)
# 7   ResNet50           DefaultAug        Mid-Range  0.6853 (0.6776, 0.6943)
# 8   ResNet50  DefaultAug+Gaussian          Highest  0.6075 (0.5864, 0.6331)
# 9   ResNet50  DefaultAug+Gaussian  In-Distribution  0.7962 (0.7880, 0.8055)
# 10  ResNet50  DefaultAug+Gaussian           Lowest  0.7674 (0.7621, 0.7724)
# 11  ResNet50  DefaultAug+Gaussian        Mid-Range  0.7206 (0.7141, 0.7262)
# 12  ResNet50       DefaultAug+S&P          Highest  0.6255 (0.6051, 0.6454)
# 13  ResNet50       DefaultAug+S&P  In-Distribution  0.7808 (0.7717, 0.7907)
# 14  ResNet50       DefaultAug+S&P           Lowest  0.7697 (0.7672, 0.7720)
# 15  ResNet50       DefaultAug+S&P        Mid-Range  0.7394 (0.7367, 0.7422)
# 16  ResNet50             Gaussian          Highest  0.4629 (0.4424, 0.4853)
# 17  ResNet50             Gaussian  In-Distribution  0.6540 (0.6321, 0.6740)
# 18  ResNet50             Gaussian           Lowest  0.6259 (0.6188, 0.6327)
# 19  ResNet50             Gaussian        Mid-Range  0.5853 (0.5790, 0.5917)
# 20  ResNet50                Mixed          Highest  0.6501 (0.6314, 0.6718)
# 21  ResNet50                Mixed  In-Distribution  0.8086 (0.8034, 0.8141)
# 22  ResNet50                Mixed           Lowest  0.7912 (0.7889, 0.7938)
# 23  ResNet50                Mixed        Mid-Range  0.7518 (0.7483, 0.7556)
# 24  ResNet50          Salt&Pepper          Highest  0.4930 (0.4748, 0.5120)
# 25  ResNet50          Salt&Pepper  In-Distribution  0.6525 (0.6344, 0.6698)
# 26  ResNet50          Salt&Pepper           Lowest  0.6393 (0.6348, 0.6438)
# 27  ResNet50          Salt&Pepper        Mid-Range  0.6136 (0.6099, 0.6174)
# 28  Xception             Baseline          Highest  0.5899 (0.5707, 0.6092)
# 29  Xception             Baseline  In-Distribution  0.7666 (0.7392, 0.7992)
# 30  Xception             Baseline           Lowest  0.7082 (0.6983, 0.7171)
# 31  Xception             Baseline        Mid-Range  0.6016 (0.5914, 0.6118)
# 32  Xception           DefaultAug          Highest  0.6983 (0.6800, 0.7162)
# 33  Xception           DefaultAug  In-Distribution  0.8610 (0.8575, 0.8651)
# 34  Xception           DefaultAug           Lowest  0.8065 (0.8006, 0.8126)
# 35  Xception           DefaultAug        Mid-Range  0.6894 (0.6785, 0.7011)
# 36  Xception  DefaultAug+Gaussian          Highest  0.6771 (0.6574, 0.6984)
# 37  Xception  DefaultAug+Gaussian  In-Distribution  0.8301 (0.8213, 0.8384)
# 38  Xception  DefaultAug+Gaussian           Lowest  0.8076 (0.8035, 0.8121)
# 39  Xception  DefaultAug+Gaussian        Mid-Range  0.7647 (0.7601, 0.7697)
# 40  Xception       DefaultAug+S&P          Highest  0.6808 (0.6630, 0.7016)
# 41  Xception       DefaultAug+S&P  In-Distribution  0.8242 (0.8131, 0.8350)
# 42  Xception       DefaultAug+S&P           Lowest  0.8082 (0.8053, 0.8113)
# 43  Xception       DefaultAug+S&P        Mid-Range  0.7714 (0.7680, 0.7750)
# 44  Xception             Gaussian          Highest  0.5914 (0.5726, 0.6122)
# 45  Xception             Gaussian  In-Distribution  0.7475 (0.7270, 0.7680)
# 46  Xception             Gaussian           Lowest  0.7192 (0.7127, 0.7261)
# 47  Xception             Gaussian        Mid-Range  0.6767 (0.6703, 0.6832)
# 48  Xception                Mixed          Highest  0.7030 (0.6871, 0.7211)
# 49  Xception                Mixed  In-Distribution  0.8430 (0.8371, 0.8495)
# 50  Xception                Mixed           Lowest  0.8222 (0.8197, 0.8246)
# 51  Xception                Mixed        Mid-Range  0.7734 (0.7700, 0.7773)
# 52  Xception          Salt&Pepper          Highest  0.5543 (0.5363, 0.5726)
# 53  Xception          Salt&Pepper  In-Distribution  0.6910 (0.6598, 0.7223)
# 54  Xception          Salt&Pepper           Lowest  0.6786 (0.6722, 0.6847)
# 55  Xception          Salt&Pepper        Mid-Range  0.6461 (0.6408, 0.6513)
